# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('datasets/covid19.csv')

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 32060            NaN  Sao Tome and Principe   0.186360   6.613081  5/21/20
# 32061            NaN                  Yemen  15.552727  48.516388  5/21/20
# 32062            NaN                Comoros -11.645500  43.333300  5/21/20
# 32063            NaN             Tajikistan  38.861034  71.276093  5/21/20
# 32064            NaN                Lesotho -29.609988  28.233608  5/21/20
#
#        Confirmed  Deaths  Recovered
# ...

# %%
#Kita mau bandingkan dan analisis negara indonesia dan singapura, jumlah kasus terkonfirmasi covid 2020

# %%
#kita lakukan filtering indonsia
data_indo = df[df['Country/Region'] == 'Indonesia']

# %%
data_indo
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 132              NaN      Indonesia -0.7893  113.9213  1/22/20          0
# 397              NaN      Indonesia -0.7893  113.9213  1/23/20          0
# 662              NaN      Indonesia -0.7893  113.9213  1/24/20          0
# 927              NaN      Indonesia -0.7893  113.9213  1/25/20          0
# 1192             NaN      Indonesia -0.7893  113.9213  1/26/20          0
# ...              ...            ...     ...       ...      ...        ...
# 30872            NaN      Indonesia -0.7893  113.9213  5/17/20      17514
# 31137            NaN      Indonesia -0.7893  113.9213  5/18/20      18010
# 31402            NaN      Indonesia -0.7893  113.9213  5/19/20      18496
# 31667            NaN      Indonesia -0.7893  113.9213  5/20/20      19189
# 31932            NaN      Indonesia -0.7893  113.9213  5/21/20      20162
#
#        Deaths  Recovered
# 132         0          0
# 397         0          0
# ...

# %%
# kita filtering juga singapura
data_singapura = df[df['Country/Region']== 'Singapore']

# %%
data_singapura
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 196              NaN      Singapore  1.2833  103.8333  1/22/20          0
# 461              NaN      Singapore  1.2833  103.8333  1/23/20          1
# 726              NaN      Singapore  1.2833  103.8333  1/24/20          3
# 991              NaN      Singapore  1.2833  103.8333  1/25/20          3
# 1256             NaN      Singapore  1.2833  103.8333  1/26/20          4
# ...              ...            ...     ...       ...      ...        ...
# 30936            NaN      Singapore  1.2833  103.8333  5/17/20      28038
# 31201            NaN      Singapore  1.2833  103.8333  5/18/20      28343
# 31466            NaN      Singapore  1.2833  103.8333  5/19/20      28794
# 31731            NaN      Singapore  1.2833  103.8333  5/20/20      29364
# 31996            NaN      Singapore  1.2833  103.8333  5/21/20      29812
#
#        Deaths  Recovered
# 196         0          0
# 461         0          0
# ...

# %%
#kita filter untuk data yang terkonfimasi covid saja
conf_indo = data_indo[data_indo['Confirmed']>0]

conf_singa = data_singapura[data_singapura['Confirmed']>0]

# %%
conf_indo
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213   3/2/20          2
# 10997            NaN      Indonesia -0.7893  113.9213   3/3/20          2
# 11262            NaN      Indonesia -0.7893  113.9213   3/4/20          2
# 11527            NaN      Indonesia -0.7893  113.9213   3/5/20          2
# 11792            NaN      Indonesia -0.7893  113.9213   3/6/20          4
# ...              ...            ...     ...       ...      ...        ...
# 30872            NaN      Indonesia -0.7893  113.9213  5/17/20      17514
# 31137            NaN      Indonesia -0.7893  113.9213  5/18/20      18010
# 31402            NaN      Indonesia -0.7893  113.9213  5/19/20      18496
# 31667            NaN      Indonesia -0.7893  113.9213  5/20/20      19189
# 31932            NaN      Indonesia -0.7893  113.9213  5/21/20      20162
#
#        Deaths  Recovered
# 10732       0          0
# 10997       0          0
# ...

# %%
conf_singa
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 461              NaN      Singapore  1.2833  103.8333  1/23/20          1
# 726              NaN      Singapore  1.2833  103.8333  1/24/20          3
# 991              NaN      Singapore  1.2833  103.8333  1/25/20          3
# 1256             NaN      Singapore  1.2833  103.8333  1/26/20          4
# 1521             NaN      Singapore  1.2833  103.8333  1/27/20          5
# ...              ...            ...     ...       ...      ...        ...
# 30936            NaN      Singapore  1.2833  103.8333  5/17/20      28038
# 31201            NaN      Singapore  1.2833  103.8333  5/18/20      28343
# 31466            NaN      Singapore  1.2833  103.8333  5/19/20      28794
# 31731            NaN      Singapore  1.2833  103.8333  5/20/20      29364
# 31996            NaN      Singapore  1.2833  103.8333  5/21/20      29812
#
#        Deaths  Recovered
# 461         0          0
# 726         0          0
# ...

# %%
#menyamakan sumbu x berdasarkan hari, ubah time data date

# %%
conf_indo['Date'] = pd.to_datetime(conf_indo['Date'])

conf_singa['Date'] = pd.to_datetime(conf_singa['Date'])
# Out:
# <ipython-input-19-f46936293f33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf_indo['Date'] = pd.to_datetime(conf_indo['Date'])
# <ipython-input-19-f46936293f33>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf_singa['Date'] = pd.to_datetime(conf_singa['Date'])

# %%
conf_indo.head()
# Out:
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
#
#        Deaths  Recovered
# 10732       0          0
# 10997       0          0
# 11262       0          0
# 11527       0          0
# 11792       0          0

# %%
conf_singa.head()
# Out:
#      Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 461             NaN      Singapore  1.2833  103.8333 2020-01-23          1
# 726             NaN      Singapore  1.2833  103.8333 2020-01-24          3
# 991             NaN      Singapore  1.2833  103.8333 2020-01-25          3
# 1256            NaN      Singapore  1.2833  103.8333 2020-01-26          4
# 1521            NaN      Singapore  1.2833  103.8333 2020-01-27          5
#
#       Deaths  Recovered
# 461        0          0
# 726        0          0
# 991        0          0
# 1256       0          0
# 1521       0          0

# %%
#buat kolom basu untuk menyamakan date untuk tau hari ke berapa
conf_indo['Basedate'] = pd.to_datetime('2020-03-02')
conf_singa['Basedate'] = pd.to_datetime('2020-01-23')
# Out:
# <ipython-input-23-590e53fa5865>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf_indo['Basedate'] = pd.to_datetime('2020-03-02')
# <ipython-input-23-590e53fa5865>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf_singa['Basedate'] = pd.to_datetime('2020-01-23')

# %%
conf_indo.head()
# Out:
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
#
#        Deaths  Recovered   Basedate
# 10732       0          0 2020-03-02
# 10997       0          0 2020-03-02
# 11262       0          0 2020-03-02
# 11527       0          0 2020-03-02
# 11792       0          0 2020-03-02

# %%
#buat kolom Hari ke
conf_indo['Harike'] = conf_indo['Date'] - conf_indo['Basedate']

conf_singa['Harike'] = conf_singa['Date'] - conf_singa['Basedate']
# Out:
# <ipython-input-28-1d0abc0e6906>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf_indo['Harike'] = conf_indo['Date'] - conf_indo['Basedate']
# <ipython-input-28-1d0abc0e6906>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf_singa['Harike'] = conf_singa['Date'] - conf_singa['Basedate']

# %%
conf_singa.head()
# Out:
#      Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 461             NaN      Singapore  1.2833  103.8333 2020-01-23          1
# 726             NaN      Singapore  1.2833  103.8333 2020-01-24          3
# 991             NaN      Singapore  1.2833  103.8333 2020-01-25          3
# 1256            NaN      Singapore  1.2833  103.8333 2020-01-26          4
# 1521            NaN      Singapore  1.2833  103.8333 2020-01-27          5
#
#       Deaths  Recovered   Basedate Hari ke Harike
# 461        0          0 2020-01-23  0 days 0 days
# 726        0          0 2020-01-23  1 days 1 days
# 991        0          0 2020-01-23  2 days 2 days
# 1256       0          0 2020-01-23  3 days 3 days
# 1521       0          0 2020-01-23  4 days 4 days

# %%
#ubah hari ke numerik biar lebih mudah diolah

conf_indo.Harike = conf_indo.Harike/pd.Timedelta(1, unit='d')

conf_singa.Harike = conf_singa.Harike/pd.Timedelta(1, unit='d')
# Out:
# c:\users\aspire e14\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
#visualisasi kan ke grafik

plt.plot(conf_indo.Harike, conf_indo.Confirmed, color='red',ls='-.', marker='+', markersize=1)
plt.plot(conf_singa.Harike, conf_singa.Confirmed, ls = ':')
plt.title('junmla perbandingan kasus covid indonesia dan singapura')
plt.xlabel('Hari ke-')
plt.ylabel('Jumlah confirmed corona')
plt.legend(['Indonesia', ['Singapore']])
plt.xlim(0,85)
plt.show()
